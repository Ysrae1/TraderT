# %%
import os,sys,time
import numpy as np
import matplotlib.pyplot as plt
import h5py
# import torch
# import torch.nn as nn
# import torch.nn.init as init
# import torch.optim as optim
import copy
import mlx.core as mx
import mlx.nn as nn
import mlx.optimizers as optim

# from torch.utils.data import Dataset, TensorDataset, DataLoader
# import torch.optim.lr_scheduler as lr_scheduler

from datetime import datetime

_dtype_ = mx.float32

class PP_MLP(nn.Module): # Price Pridiction

    def __init__(self, init_method = 'uniform'):

        super(PP_MLP, self).__init__() # 3 layers of 8
        self.layer1 = nn.Linear(14, 10)  
        self.layer2 = nn.Linear(10, 5)
        self.layer3 = nn.Linear(5, 3)
        self.output = nn.Linear(3, 1)
        self.relu = nn.ReLU()
    
    def __call__(self, x):
        
        x = self.relu(self.layer1(x)) 
        x = self.relu(self.layer2(x)) 
        x = self.relu(self.layer3(x)) 
        return self.output(x) 
    
class H5Dataset(Dataset):
    def __init__(self, file_path, norm_flag):
        self.file_path = file_path
        self.dataset = {}

        with h5py.File(self.file_path, 'r') as file:
            self.dataset['inputs'] = file['inputs'][:]
            self.dataset['outputs'] = file['outputs'][:]

        if norm_flag == 'n':
            self.normalization()
        if norm_flag == 'd':
            pass
    
    def __len__(self):
        return len(self.dataset['inputs'])

    def __getitem__(self, idx):
        input_data = torch.tensor(self.dataset['inputs'][idx], dtype=torch.float32)
        output_data = torch.tensor(self.dataset['outputs'][idx], dtype=torch.float32)
        return input_data, output_data
    
    def normalization(self):
        inputs = self.dataset['inputs']
        outputs = self.dataset['outputs']
        min_vals_i = inputs.min(axis=0)  
        max_vals_i = inputs.max(axis=0) 
        min_vals_o = outputs.min(axis=0)  
        max_vals_o = outputs.max(axis=0)         

        ranges_i = max_vals_i - min_vals_i
        ranges_i[ranges_i == 0] = 1

        if (max_vals_o - min_vals_o)!= 0:
            ranges_o = max_vals_o - min_vals_o
        else:
            ranges_o = 1

        self.dataset['inputs'] = (inputs - min_vals_i) / ranges_i
        self.dataset['outputs'] = ((outputs - min_vals_o) / ranges_o).squeeze()

def set_learning_rate(optimizer, lr):
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
dataset_train = H5Dataset('../data/lob_data/lob_data_train.h5','n')
dataset_train_dn = H5Dataset('../data/lob_data/lob_data_train.h5','d')

dataset_verif = H5Dataset('../data/lob_data/lob_data_verif.h5','n')
dataset_verif_dn = H5Dataset('../data/lob_data/lob_data_verif.h5','d')

dataset_test = H5Dataset('../data/lob_data/lob_data_test.h5','n')
dataset_test_dn = H5Dataset('../data/lob_data/lob_data_test.h5','d')

# %%
PPMLP_model = PP_MLP(init_method = 'uniform').to(_device_)

loader_train = DataLoader(dataset_train, batch_size=4096, shuffle = True)
loader_verif = DataLoader(dataset_verif, batch_size=4096, shuffle = True)

criterion = nn.MSELoss()
optimizer = optim.Adam(PPMLP_model.parameters(), lr=0.001)

model_save_path_MLP = 'PPMLP_model.pt'
optimizer_save_path_MLP = 'PPMLP_optimizer.pt'

# %%
# MLP Training
continue_training = input("Do you want to continue training or start a new one? (c/n): ").lower() == 'c'

if continue_training and os.path.exists(model_save_path_MLP) and os.path.exists(optimizer_save_path_MLP):
    
    PPMLP_model.load_state_dict(torch.load(model_save_path_MLP))
    optimizer.load_state_dict(torch.load(optimizer_save_path_MLP))
    
    print("Continuing training from saved state.")
else:
    print("Starting training from scratch.")

epoch_losses_train = []
epoch_losses_verif = []

max_epochs = 100

patience = 10

timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')

filename = f'MLP_loss_train & verif_{timestamp}.dat'

with open(filename, 'w') as f:

    best_loss_verif = float('inf')
    patience_counter = 0

    for epoch in range(max_epochs):

        PPMLP_model.train()  

        running_loss_train = 0.0

        print(f"Start epoch {epoch+1}.\n")

        for batch_idx, (inputs, labels) in enumerate(loader_train):
    
            inputs, labels = inputs.to(_device_), labels.to(_device_).unsqueeze(1)
            
            optimizer.zero_grad()

            outputs = PPMLP_model(inputs)

            loss = criterion(outputs, labels)

            loss.backward()

            optimizer.step()

            running_loss_train += loss.item()

            if ((batch_idx+1) % 500 == 0) or batch_idx == 0:

                print(f"Epoch {epoch+1}, Batch {batch_idx+1}, Batch Loss_train: {loss.item()}")

        print('\n')

        PPMLP_model.eval()

        with torch.no_grad():

            running_loss_verif = 0.0

            for batch_idx, (inputs, labels) in enumerate(loader_verif):

                inputs, labels = inputs.to(_device_), labels.to(_device_).unsqueeze(1)

                outputs = PPMLP_model(inputs)

                loss = criterion(outputs, labels)

                running_loss_verif += loss.item()



        epoch_loss_train = running_loss_train/len(loader_train)
        epoch_loss_verif = running_loss_verif/len(loader_verif)

        epoch_losses_train.append(epoch_loss_train)
        epoch_losses_verif.append(epoch_loss_verif)

        # scheduler_step.step()

        f.write(f'Epoch {epoch+1}, Loss_train: {epoch_loss_train}, Loss_verif: {epoch_loss_verif}\n')
        print(f'Epoch {epoch+1}, Epoch Average Loss_train: {epoch_loss_train}, Epoch Average Loss_verif: {epoch_loss_verif}\n')

        if epoch_loss_verif < best_loss_verif:
            best_loss_verif = epoch_loss_verif
            patience_counter = 0
            torch.save(PPMLP_model.state_dict(), model_save_path_MLP)
            torch.save(optimizer.state_dict(), optimizer_save_path_MLP)
        else :
            patience_counter += 1
        
        if patience_counter >= patience:
            print(f'Early stopping triggered at epoch {epoch+1}')
            break
    
    print('\n')
# Out:
# Starting training from scratch.
# Start epoch 1.
#
# Epoch 1, Batch 1, Batch Loss_train: 0.01753949746489525
# Epoch 1, Batch 500, Batch Loss_train: 0.002377919852733612
# Epoch 1, Batch 1000, Batch Loss_train: 0.002458134200423956
# Epoch 1, Batch 1500, Batch Loss_train: 0.0024298885837197304
# Epoch 1, Batch 2000, Batch Loss_train: 0.0023657670244574547
# Epoch 1, Batch 2500, Batch Loss_train: 0.002376605523750186
# Epoch 1, Batch 3000, Batch Loss_train: 0.002359617268666625
# Epoch 1, Batch 3500, Batch Loss_train: 0.0024143713526427746
# Epoch 1, Batch 4000, Batch Loss_train: 0.0022382247261703014
#
#
# Epoch 1, Epoch Average Loss_train: 0.0025669847437390604, Epoch Average Loss_verif: 0.0022412740726044287
#
# Start epoch 2.
#
# Epoch 2, Batch 1, Batch Loss_train: 0.0023745885118842125
# Epoch 2, Batch 500, Batch Loss_train: 0.002402906771749258
# Epoch 2, Batch 1000, Batch Loss_train: 0.002298867329955101
# Epoch 2, Batch 1500, Batch Loss_train: 0.0023274896666407585
# Epoch 2, Batch 2000, Batch Loss_train: 0.002243473893031478
# Epoch 2, Batch 2500, Batch Loss_train: 0.00231582997366786
# Epoch 2, Batch 3000, Batch Loss_train: 0.002278329338878393
# Epoch 2, Batch 3500, Batch Loss_train: 0.00235296250320971
# Epoch 2, Batch 4000, Batch Loss_train: 0.0023399987258017063
#
#
# Epoch 2, Epoch Average Loss_train: 0.002293721915663969, Epoch Average Loss_verif: 0.002228651169977009
#
# Start epoch 3.
#
# Epoch 3, Batch 1, Batch Loss_train: 0.002252025529742241
# Epoch 3, Batch 500, Batch Loss_train: 0.0022887680679559708
# Epoch 3, Batch 1000, Batch Loss_train: 0.0022708741016685963
# Epoch 3, Batch 1500, Batch Loss_train: 0.0023670196533203125
# Epoch 3, Batch 2000, Batch Loss_train: 0.002366771223023534
# Epoch 3, Batch 2500, Batch Loss_train: 0.0022972647566348314
# Epoch 3, Batch 3000, Batch Loss_train: 0.002150301355868578
# Epoch 3, Batch 3500, Batch Loss_train: 0.0022738755214959383
# Epoch 3, Batch 4000, Batch Loss_train: 0.0022893324494361877
#
#
# Epoch 3, Epoch Average Loss_train: 0.002286732593468541, Epoch Average Loss_verif: 0.0022207495402850365
#
# Start epoch 4.
#
# Epoch 4, Batch 1, Batch Loss_train: 0.0023037067148834467
# Epoch 4, Batch 500, Batch Loss_train: 0.0022465684451162815
# Epoch 4, Batch 1000, Batch Loss_train: 0.002362332073971629
# Epoch 4, Batch 1500, Batch Loss_train: 0.0021509546786546707
# Epoch 4, Batch 2000, Batch Loss_train: 0.002316837664693594
# Epoch 4, Batch 2500, Batch Loss_train: 0.002357492921873927
# Epoch 4, Batch 3000, Batch Loss_train: 0.0022660281974822283
# Epoch 4, Batch 3500, Batch Loss_train: 0.0023017623461782932
# Epoch 4, Batch 4000, Batch Loss_train: 0.002231770195066929
#
#
# Epoch 4, Epoch Average Loss_train: 0.002267173431274865, Epoch Average Loss_verif: 0.0022113822925234777
#
# Start epoch 5.
#
# Epoch 5, Batch 1, Batch Loss_train: 0.0023436853662133217
# Epoch 5, Batch 500, Batch Loss_train: 0.002192786429077387
# Epoch 5, Batch 1000, Batch Loss_train: 0.0021480191498994827
# Epoch 5, Batch 1500, Batch Loss_train: 0.0023250910453498363
# Epoch 5, Batch 2000, Batch Loss_train: 0.0022941313218325377
# Epoch 5, Batch 2500, Batch Loss_train: 0.002165724989026785
# Epoch 5, Batch 3000, Batch Loss_train: 0.002349306596443057
# Epoch 5, Batch 3500, Batch Loss_train: 0.002220815047621727
# Epoch 5, Batch 4000, Batch Loss_train: 0.0021676956675946712
#
#
# Epoch 5, Epoch Average Loss_train: 0.002256761855023631, Epoch Average Loss_verif: 0.0021967896641934175
#
# Start epoch 6.
#
# Epoch 6, Batch 1, Batch Loss_train: 0.002354010473936796
# Epoch 6, Batch 500, Batch Loss_train: 0.0022543235681951046
# Epoch 6, Batch 1000, Batch Loss_train: 0.0022782792802900076
# Epoch 6, Batch 1500, Batch Loss_train: 0.002350484486669302
# Epoch 6, Batch 2000, Batch Loss_train: 0.002252498408779502
# Epoch 6, Batch 2500, Batch Loss_train: 0.0023412357550114393
# Epoch 6, Batch 3000, Batch Loss_train: 0.0022131477016955614
# Epoch 6, Batch 3500, Batch Loss_train: 0.002244180766865611
# Epoch 6, Batch 4000, Batch Loss_train: 0.002212472492828965
#
#
# Epoch 6, Epoch Average Loss_train: 0.002252812564356045, Epoch Average Loss_verif: 0.0021912754199628053
#
# Start epoch 7.
#
# Epoch 7, Batch 1, Batch Loss_train: 0.002226637676358223
# Epoch 7, Batch 500, Batch Loss_train: 0.0021529116202145815
# Epoch 7, Batch 1000, Batch Loss_train: 0.002213404281064868
# Epoch 7, Batch 1500, Batch Loss_train: 0.002204327844083309
# Epoch 7, Batch 2000, Batch Loss_train: 0.0021691916044801474
# Epoch 7, Batch 2500, Batch Loss_train: 0.0022072517313063145
# Epoch 7, Batch 3000, Batch Loss_train: 0.002339285798370838
# Epoch 7, Batch 3500, Batch Loss_train: 0.0020858184434473515
# Epoch 7, Batch 4000, Batch Loss_train: 0.0022947564721107483
#
#
# Epoch 7, Epoch Average Loss_train: 0.0022464017482932684, Epoch Average Loss_verif: 0.00217586264951085
#
# Start epoch 8.
#
# Epoch 8, Batch 1, Batch Loss_train: 0.0021641463972628117
# Epoch 8, Batch 500, Batch Loss_train: 0.0021623570937663317
# Epoch 8, Batch 1000, Batch Loss_train: 0.002278625499457121
# Epoch 8, Batch 1500, Batch Loss_train: 0.002309610368683934
# Epoch 8, Batch 2000, Batch Loss_train: 0.0022819372825324535
# Epoch 8, Batch 2500, Batch Loss_train: 0.002319329185411334
# Epoch 8, Batch 3000, Batch Loss_train: 0.0023031760938465595
# Epoch 8, Batch 3500, Batch Loss_train: 0.002300793770700693
# Epoch 8, Batch 4000, Batch Loss_train: 0.00236068619415164
#
#
# Epoch 8, Epoch Average Loss_train: 0.0022383587315025185, Epoch Average Loss_verif: 0.002190832725603816
#
# Start epoch 9.
#
# Epoch 9, Batch 1, Batch Loss_train: 0.002276357728987932
# Epoch 9, Batch 500, Batch Loss_train: 0.0023208865895867348
# Epoch 9, Batch 1000, Batch Loss_train: 0.0022056333255022764
# Epoch 9, Batch 1500, Batch Loss_train: 0.002332409843802452
# Epoch 9, Batch 2000, Batch Loss_train: 0.0022498227190226316
# Epoch 9, Batch 2500, Batch Loss_train: 0.0021643470972776413
# Epoch 9, Batch 3000, Batch Loss_train: 0.002193185966461897
# Epoch 9, Batch 3500, Batch Loss_train: 0.002347961999475956
# Epoch 9, Batch 4000, Batch Loss_train: 0.002315201796591282
#
#
# Epoch 9, Epoch Average Loss_train: 0.002234774336095789, Epoch Average Loss_verif: 0.002181013572983165
#
# Start epoch 10.
#
# Epoch 10, Batch 1, Batch Loss_train: 0.002334257587790489
# Epoch 10, Batch 500, Batch Loss_train: 0.0022463202476501465
# Epoch 10, Batch 1000, Batch Loss_train: 0.002230401849374175
# Epoch 10, Batch 1500, Batch Loss_train: 0.0021996102295815945
# Epoch 10, Batch 2000, Batch Loss_train: 0.0022694070357829332
# Epoch 10, Batch 2500, Batch Loss_train: 0.002276273909956217
# Epoch 10, Batch 3000, Batch Loss_train: 0.0022789733484387398
# Epoch 10, Batch 3500, Batch Loss_train: 0.0022851708345115185
# Epoch 10, Batch 4000, Batch Loss_train: 0.002150772139430046
#
#
# Epoch 10, Epoch Average Loss_train: 0.002233307458543068, Epoch Average Loss_verif: 0.0021771705209989857
#
# Start epoch 11.
#
# Epoch 11, Batch 1, Batch Loss_train: 0.0021958635188639164
# Epoch 11, Batch 500, Batch Loss_train: 0.002321947365999222
# Epoch 11, Batch 1000, Batch Loss_train: 0.002232409780845046
# Epoch 11, Batch 1500, Batch Loss_train: 0.002278486732393503
# Epoch 11, Batch 2000, Batch Loss_train: 0.002135639311745763
# Epoch 11, Batch 2500, Batch Loss_train: 0.0022592153400182724
# Epoch 11, Batch 3000, Batch Loss_train: 0.0022020337637513876
# Epoch 11, Batch 3500, Batch Loss_train: 0.0022348477505147457
# Epoch 11, Batch 4000, Batch Loss_train: 0.0022509759292006493
#
#
# Epoch 11, Epoch Average Loss_train: 0.0022321897869132003, Epoch Average Loss_verif: 0.002174653143875824
#
# Start epoch 12.
#
# Epoch 12, Batch 1, Batch Loss_train: 0.002144847298040986
# Epoch 12, Batch 500, Batch Loss_train: 0.0023341868072748184
# Epoch 12, Batch 1000, Batch Loss_train: 0.002330382587388158
# Epoch 12, Batch 1500, Batch Loss_train: 0.002153803128749132
# Epoch 12, Batch 2000, Batch Loss_train: 0.00212308531627059
# Epoch 12, Batch 2500, Batch Loss_train: 0.0022358556743711233
# Epoch 12, Batch 3000, Batch Loss_train: 0.0022129840217530727
# Epoch 12, Batch 3500, Batch Loss_train: 0.0022610367741435766
# Epoch 12, Batch 4000, Batch Loss_train: 0.0023046820424497128
#
#
# Epoch 12, Epoch Average Loss_train: 0.0022316770536871732, Epoch Average Loss_verif: 0.0021813145723854383
#
# Start epoch 13.
#
# Epoch 13, Batch 1, Batch Loss_train: 0.0022701954003423452
# Epoch 13, Batch 500, Batch Loss_train: 0.0021941668819636106
# Epoch 13, Batch 1000, Batch Loss_train: 0.002169205341488123
# Epoch 13, Batch 1500, Batch Loss_train: 0.0021926071494817734
# Epoch 13, Batch 2000, Batch Loss_train: 0.002216143999248743
# Epoch 13, Batch 2500, Batch Loss_train: 0.002309447154402733
# Epoch 13, Batch 3000, Batch Loss_train: 0.002298823557794094
# Epoch 13, Batch 3500, Batch Loss_train: 0.0022132715675979853
# Epoch 13, Batch 4000, Batch Loss_train: 0.0022024407517164946
#
#
# Epoch 13, Epoch Average Loss_train: 0.0022309874856933647, Epoch Average Loss_verif: 0.002167637616887505
#
# Start epoch 14.
#
# Epoch 14, Batch 1, Batch Loss_train: 0.002278328640386462
# Epoch 14, Batch 500, Batch Loss_train: 0.002264372305944562
# Epoch 14, Batch 1000, Batch Loss_train: 0.002164751524105668
# Epoch 14, Batch 1500, Batch Loss_train: 0.002116796560585499
# Epoch 14, Batch 2000, Batch Loss_train: 0.002375692129135132
# Epoch 14, Batch 2500, Batch Loss_train: 0.002261463087052107
# Epoch 14, Batch 3000, Batch Loss_train: 0.002236210508272052
# Epoch 14, Batch 3500, Batch Loss_train: 0.0021842517890036106
# Epoch 14, Batch 4000, Batch Loss_train: 0.0022513587027788162
#
#
# Epoch 14, Epoch Average Loss_train: 0.002230469262172258, Epoch Average Loss_verif: 0.0021720516222462046
#
# Start epoch 15.
#
# Epoch 15, Batch 1, Batch Loss_train: 0.0021692474838346243
# Epoch 15, Batch 500, Batch Loss_train: 0.002184963086619973
# Epoch 15, Batch 1000, Batch Loss_train: 0.0022584516555070877
# Epoch 15, Batch 1500, Batch Loss_train: 0.0021924548782408237
# Epoch 15, Batch 2000, Batch Loss_train: 0.002319144317880273
# Epoch 15, Batch 2500, Batch Loss_train: 0.0022950053680688143
# Epoch 15, Batch 3000, Batch Loss_train: 0.002258454216644168
# Epoch 15, Batch 3500, Batch Loss_train: 0.002188824350014329
# Epoch 15, Batch 4000, Batch Loss_train: 0.0022561305668205023
#
#
# Epoch 15, Epoch Average Loss_train: 0.002230387737079267, Epoch Average Loss_verif: 0.0021796733552272496
#
# Start epoch 16.
#
# Epoch 16, Batch 1, Batch Loss_train: 0.002182476222515106
# Epoch 16, Batch 500, Batch Loss_train: 0.0022250176407396793
# Epoch 16, Batch 1000, Batch Loss_train: 0.0022127339616417885
# Epoch 16, Batch 1500, Batch Loss_train: 0.0022887992672622204
# Epoch 16, Batch 2000, Batch Loss_train: 0.002228775527328253
# Epoch 16, Batch 2500, Batch Loss_train: 0.002219153568148613
# Epoch 16, Batch 3000, Batch Loss_train: 0.0021256557665765285
# Epoch 16, Batch 3500, Batch Loss_train: 0.0021768969018012285
# Epoch 16, Batch 4000, Batch Loss_train: 0.0021751290187239647
#
#
# Epoch 16, Epoch Average Loss_train: 0.0022295715186027875, Epoch Average Loss_verif: 0.0021773902370374556
#
# Start epoch 17.
#
# Epoch 17, Batch 1, Batch Loss_train: 0.0022915774025022984
# Epoch 17, Batch 500, Batch Loss_train: 0.002191693987697363
# Epoch 17, Batch 1000, Batch Loss_train: 0.0020595986861735582
# Epoch 17, Batch 1500, Batch Loss_train: 0.0021263116504997015
# Epoch 17, Batch 2000, Batch Loss_train: 0.0021692749578505754
# Epoch 17, Batch 2500, Batch Loss_train: 0.002339462051168084
# Epoch 17, Batch 3000, Batch Loss_train: 0.0021372796036303043
# Epoch 17, Batch 3500, Batch Loss_train: 0.0023322436027228832
# Epoch 17, Batch 4000, Batch Loss_train: 0.0022706505842506886
#
#
# Epoch 17, Epoch Average Loss_train: 0.002229523085320797, Epoch Average Loss_verif: 0.0021676426143627425
#
# Start epoch 18.
#
# Epoch 18, Batch 1, Batch Loss_train: 0.0022694796789437532
# Epoch 18, Batch 500, Batch Loss_train: 0.0021977464202791452
# Epoch 18, Batch 1000, Batch Loss_train: 0.0022566255647689104
# Epoch 18, Batch 1500, Batch Loss_train: 0.0022069839760661125
# Epoch 18, Batch 2000, Batch Loss_train: 0.0021428298205137253
# Epoch 18, Batch 2500, Batch Loss_train: 0.0022008735686540604
# Epoch 18, Batch 3000, Batch Loss_train: 0.002212907886132598
# Epoch 18, Batch 3500, Batch Loss_train: 0.0022202269174158573
# Epoch 18, Batch 4000, Batch Loss_train: 0.0021889847703278065
#
#
# Epoch 18, Epoch Average Loss_train: 0.0022292636667965893, Epoch Average Loss_verif: 0.002173287617832205
#
# Start epoch 19.
#
# Epoch 19, Batch 1, Batch Loss_train: 0.0022924512159079313
# Epoch 19, Batch 500, Batch Loss_train: 0.002204644726589322
# Epoch 19, Batch 1000, Batch Loss_train: 0.0022611471358686686
# Epoch 19, Batch 1500, Batch Loss_train: 0.002375504933297634
# Epoch 19, Batch 2000, Batch Loss_train: 0.0022820972371846437
# Epoch 19, Batch 2500, Batch Loss_train: 0.0022149463184177876
# Epoch 19, Batch 3000, Batch Loss_train: 0.002366483211517334
# Epoch 19, Batch 3500, Batch Loss_train: 0.0022009278181940317
# Epoch 19, Batch 4000, Batch Loss_train: 0.002199889626353979
#
#
# Epoch 19, Epoch Average Loss_train: 0.0022289262390812192, Epoch Average Loss_verif: 0.002167557859232984
#
# Start epoch 20.
#
# Epoch 20, Batch 1, Batch Loss_train: 0.002159676281735301
# Epoch 20, Batch 500, Batch Loss_train: 0.002302387496456504
# Epoch 20, Batch 1000, Batch Loss_train: 0.0022960545029491186
# Epoch 20, Batch 1500, Batch Loss_train: 0.002215127693489194
# Epoch 20, Batch 2000, Batch Loss_train: 0.002159508178010583
# Epoch 20, Batch 2500, Batch Loss_train: 0.002243855968117714
# Epoch 20, Batch 3000, Batch Loss_train: 0.0022080549970269203
# Epoch 20, Batch 3500, Batch Loss_train: 0.0023043311666697264
# Epoch 20, Batch 4000, Batch Loss_train: 0.0023577839601784945
#
#
# Epoch 20, Epoch Average Loss_train: 0.002228561388742357, Epoch Average Loss_verif: 0.0021823917298238985
#
# Start epoch 21.
#
# Epoch 21, Batch 1, Batch Loss_train: 0.0023786670062690973
# Epoch 21, Batch 500, Batch Loss_train: 0.002195788314566016
# Epoch 21, Batch 1000, Batch Loss_train: 0.0022351951338350773
# Epoch 21, Batch 1500, Batch Loss_train: 0.002163360361009836
# Epoch 21, Batch 2000, Batch Loss_train: 0.002220626687631011
# Epoch 21, Batch 2500, Batch Loss_train: 0.0021872154902666807
# Epoch 21, Batch 3000, Batch Loss_train: 0.002244448522105813
# Epoch 21, Batch 3500, Batch Loss_train: 0.00224302988499403
# Epoch 21, Batch 4000, Batch Loss_train: 0.0021902199368923903
#
#
# Epoch 21, Epoch Average Loss_train: 0.002228093025664924, Epoch Average Loss_verif: 0.002191580243242281
#
# Start epoch 22.
#
# Epoch 22, Batch 1, Batch Loss_train: 0.0022820106241852045
# Epoch 22, Batch 500, Batch Loss_train: 0.00218688091263175
# Epoch 22, Batch 1000, Batch Loss_train: 0.0021823260467499495
# Epoch 22, Batch 1500, Batch Loss_train: 0.002185140736401081
# Epoch 22, Batch 2000, Batch Loss_train: 0.0022034940775483847
# Epoch 22, Batch 2500, Batch Loss_train: 0.0021903449669480324
# Epoch 22, Batch 3000, Batch Loss_train: 0.0022383106406778097
# Epoch 22, Batch 3500, Batch Loss_train: 0.0022100615315139294
# Epoch 22, Batch 4000, Batch Loss_train: 0.0022478022146970034
#
#
# Epoch 22, Epoch Average Loss_train: 0.0022280357862930907, Epoch Average Loss_verif: 0.0021698351983624486
#
# Start epoch 23.
#
# Epoch 23, Batch 1, Batch Loss_train: 0.002209404716268182
# Epoch 23, Batch 500, Batch Loss_train: 0.0022071190178394318
# Epoch 23, Batch 1000, Batch Loss_train: 0.002182142809033394
# Epoch 23, Batch 1500, Batch Loss_train: 0.002318745478987694
# Epoch 23, Batch 2000, Batch Loss_train: 0.0021832457277923822
# Epoch 23, Batch 2500, Batch Loss_train: 0.002117487834766507
# Epoch 23, Batch 3000, Batch Loss_train: 0.00220278138294816
# Epoch 23, Batch 3500, Batch Loss_train: 0.002235671505331993
# Epoch 23, Batch 4000, Batch Loss_train: 0.002240689704194665
#
#
# Epoch 23, Epoch Average Loss_train: 0.002227846417705484, Epoch Average Loss_verif: 0.00218041881739774
#
# Start epoch 24.
#
# Epoch 24, Batch 1, Batch Loss_train: 0.002254726830869913
# Epoch 24, Batch 500, Batch Loss_train: 0.002235023071989417
# Epoch 24, Batch 1000, Batch Loss_train: 0.0023556281812489033
# Epoch 24, Batch 1500, Batch Loss_train: 0.002134762704372406
# Epoch 24, Batch 2000, Batch Loss_train: 0.002240819623693824
# Epoch 24, Batch 2500, Batch Loss_train: 0.002194763394072652
# Epoch 24, Batch 3000, Batch Loss_train: 0.002140102442353964
# Epoch 24, Batch 3500, Batch Loss_train: 0.0021924509201198816
# Epoch 24, Batch 4000, Batch Loss_train: 0.002153716515749693
#
#
# Epoch 24, Epoch Average Loss_train: 0.002227949918457784, Epoch Average Loss_verif: 0.0021674789641342833
#
# Start epoch 25.
#
# Epoch 25, Batch 1, Batch Loss_train: 0.0022389660589396954
# Epoch 25, Batch 500, Batch Loss_train: 0.0022996433544903994
# Epoch 25, Batch 1000, Batch Loss_train: 0.002140743425115943
# Epoch 25, Batch 1500, Batch Loss_train: 0.002194897038862109
# Epoch 25, Batch 2000, Batch Loss_train: 0.0022031981498003006
# Epoch 25, Batch 2500, Batch Loss_train: 0.0021285542752593756
# Epoch 25, Batch 3000, Batch Loss_train: 0.002214668784290552
# Epoch 25, Batch 3500, Batch Loss_train: 0.002164279343560338
# Epoch 25, Batch 4000, Batch Loss_train: 0.0021363007836043835
#
#
# Epoch 25, Epoch Average Loss_train: 0.0022271959080863617, Epoch Average Loss_verif: 0.0021709450973713992
#
# Start epoch 26.
#
# Epoch 26, Batch 1, Batch Loss_train: 0.0023647600319236517
# Epoch 26, Batch 500, Batch Loss_train: 0.00226408033631742
# Epoch 26, Batch 1000, Batch Loss_train: 0.002249558689072728
# Epoch 26, Batch 1500, Batch Loss_train: 0.0023377814795821905
# Epoch 26, Batch 2000, Batch Loss_train: 0.002116831950843334
# Epoch 26, Batch 2500, Batch Loss_train: 0.002255307277664542
# Epoch 26, Batch 3000, Batch Loss_train: 0.0022856714203953743
# Epoch 26, Batch 3500, Batch Loss_train: 0.002295732032507658
# Epoch 26, Batch 4000, Batch Loss_train: 0.002251340076327324
#
#
# Epoch 26, Epoch Average Loss_train: 0.0022275005644378262, Epoch Average Loss_verif: 0.0021678964982451083
#
# Start epoch 27.
#
# Epoch 27, Batch 1, Batch Loss_train: 0.0020542526617646217
# Epoch 27, Batch 500, Batch Loss_train: 0.0021301961969584227
# Epoch 27, Batch 1000, Batch Loss_train: 0.002201293595135212
# Epoch 27, Batch 1500, Batch Loss_train: 0.002199744340032339
# Epoch 27, Batch 2000, Batch Loss_train: 0.0021660388447344303
# Epoch 27, Batch 2500, Batch Loss_train: 0.0022505128290504217
# Epoch 27, Batch 3000, Batch Loss_train: 0.002207922050729394
# Epoch 27, Batch 3500, Batch Loss_train: 0.002281731925904751
# Epoch 27, Batch 4000, Batch Loss_train: 0.0022235866636037827
#
#
# Epoch 27, Epoch Average Loss_train: 0.002227248656001273, Epoch Average Loss_verif: 0.002172547745295107
#
# Start epoch 28.
#
# Epoch 28, Batch 1, Batch Loss_train: 0.002189250197261572
# Epoch 28, Batch 500, Batch Loss_train: 0.002146015875041485
# Epoch 28, Batch 1000, Batch Loss_train: 0.0021860781125724316
# Epoch 28, Batch 1500, Batch Loss_train: 0.0021340560633689165
# Epoch 28, Batch 2000, Batch Loss_train: 0.0023095128126442432
# Epoch 28, Batch 2500, Batch Loss_train: 0.002210240578278899
# Epoch 28, Batch 3000, Batch Loss_train: 0.0022188639268279076
# Epoch 28, Batch 3500, Batch Loss_train: 0.002101556397974491
# Epoch 28, Batch 4000, Batch Loss_train: 0.002327186055481434
#
#
# Epoch 28, Epoch Average Loss_train: 0.0022268420042881663, Epoch Average Loss_verif: 0.0021698435212620477
#
# Start epoch 29.
#
# Epoch 29, Batch 1, Batch Loss_train: 0.002314826240763068
# Epoch 29, Batch 500, Batch Loss_train: 0.0021827062591910362
# Epoch 29, Batch 1000, Batch Loss_train: 0.0022560744546353817
# Epoch 29, Batch 1500, Batch Loss_train: 0.002217479282990098
# Epoch 29, Batch 2000, Batch Loss_train: 0.002308535622432828
# Epoch 29, Batch 2500, Batch Loss_train: 0.0021966921631246805
# Epoch 29, Batch 3000, Batch Loss_train: 0.0021717690397053957
# Epoch 29, Batch 3500, Batch Loss_train: 0.0021265107207000256
# Epoch 29, Batch 4000, Batch Loss_train: 0.002209442900493741
#
#
# Epoch 29, Epoch Average Loss_train: 0.002226921793069173, Epoch Average Loss_verif: 0.002171592677284606
#
# Start epoch 30.
#
# Epoch 30, Batch 1, Batch Loss_train: 0.002214038046076894
# Epoch 30, Batch 500, Batch Loss_train: 0.002290108008310199
# Epoch 30, Batch 1000, Batch Loss_train: 0.002315207850188017
# Epoch 30, Batch 1500, Batch Loss_train: 0.0020889705047011375
# Epoch 30, Batch 2000, Batch Loss_train: 0.0022215964272618294
# Epoch 30, Batch 2500, Batch Loss_train: 0.0021982465405017138
# Epoch 30, Batch 3000, Batch Loss_train: 0.0022153302561491728
# Epoch 30, Batch 3500, Batch Loss_train: 0.0022415095008909702
# Epoch 30, Batch 4000, Batch Loss_train: 0.0022203612606972456
#
#
# Epoch 30, Epoch Average Loss_train: 0.0022267341486481708, Epoch Average Loss_verif: 0.002166336240461682
#
# Start epoch 31.
#
# Epoch 31, Batch 1, Batch Loss_train: 0.002283180132508278
# Epoch 31, Batch 500, Batch Loss_train: 0.00223495508544147
# Epoch 31, Batch 1000, Batch Loss_train: 0.00219493405893445
# Epoch 31, Batch 1500, Batch Loss_train: 0.0022712149657309055
# Epoch 31, Batch 2000, Batch Loss_train: 0.0021881794091314077
# Epoch 31, Batch 2500, Batch Loss_train: 0.0022904423531144857
# Epoch 31, Batch 3000, Batch Loss_train: 0.0022523219231516123
# Epoch 31, Batch 3500, Batch Loss_train: 0.0022685881704092026
# Epoch 31, Batch 4000, Batch Loss_train: 0.002219271846115589
#
#
# Epoch 31, Epoch Average Loss_train: 0.002226499848572669, Epoch Average Loss_verif: 0.0021653706940110017
#
# Start epoch 32.
#
# Epoch 32, Batch 1, Batch Loss_train: 0.0023654582910239697
# Epoch 32, Batch 500, Batch Loss_train: 0.002179394941776991
# Epoch 32, Batch 1000, Batch Loss_train: 0.0022666826844215393
# Epoch 32, Batch 1500, Batch Loss_train: 0.002177285961806774
# Epoch 32, Batch 2000, Batch Loss_train: 0.0021940378937870264
# Epoch 32, Batch 2500, Batch Loss_train: 0.0021783115807920694
# Epoch 32, Batch 3000, Batch Loss_train: 0.0022033334244042635
# Epoch 32, Batch 3500, Batch Loss_train: 0.0023075854405760765
# Epoch 32, Batch 4000, Batch Loss_train: 0.002167628612369299
#
#
# Epoch 32, Epoch Average Loss_train: 0.002226053970836205, Epoch Average Loss_verif: 0.0021675097523257136
#
# Start epoch 33.
#
# Epoch 33, Batch 1, Batch Loss_train: 0.002422004472464323
# Epoch 33, Batch 500, Batch Loss_train: 0.0021444782614707947
# Epoch 33, Batch 1000, Batch Loss_train: 0.0022324335295706987
# Epoch 33, Batch 1500, Batch Loss_train: 0.0022066065575927496
# Epoch 33, Batch 2000, Batch Loss_train: 0.0021746507845818996
# Epoch 33, Batch 2500, Batch Loss_train: 0.0022734308149665594
# Epoch 33, Batch 3000, Batch Loss_train: 0.0022178548388183117
# Epoch 33, Batch 3500, Batch Loss_train: 0.0022953981533646584
# Epoch 33, Batch 4000, Batch Loss_train: 0.0021800589747726917
#
#
# Epoch 33, Epoch Average Loss_train: 0.0022258616158641145, Epoch Average Loss_verif: 0.0021677411351532913
#
# Start epoch 34.
#
# Epoch 34, Batch 1, Batch Loss_train: 0.0024401270784437656
# Epoch 34, Batch 500, Batch Loss_train: 0.002160092815756798
# Epoch 34, Batch 1000, Batch Loss_train: 0.0022548814304172993
# Epoch 34, Batch 1500, Batch Loss_train: 0.0021880127023905516
# Epoch 34, Batch 2000, Batch Loss_train: 0.002134562935680151
# Epoch 34, Batch 2500, Batch Loss_train: 0.002264115959405899
# Epoch 34, Batch 3000, Batch Loss_train: 0.002182004041969776
# Epoch 34, Batch 3500, Batch Loss_train: 0.002335354220122099
# Epoch 34, Batch 4000, Batch Loss_train: 0.002210598438978195
#
#
# Epoch 34, Epoch Average Loss_train: 0.0022256701105382456, Epoch Average Loss_verif: 0.0021669110245051827
#
# Start epoch 35.
#
# Epoch 35, Batch 1, Batch Loss_train: 0.0023580945562571287
# Epoch 35, Batch 500, Batch Loss_train: 0.0022921706549823284
# Epoch 35, Batch 1000, Batch Loss_train: 0.0022355271503329277
# Epoch 35, Batch 1500, Batch Loss_train: 0.0021884352900087833
# Epoch 35, Batch 2000, Batch Loss_train: 0.0022716806270182133
# Epoch 35, Batch 2500, Batch Loss_train: 0.0022830264642834663
# Epoch 35, Batch 3000, Batch Loss_train: 0.0023319763131439686
# Epoch 35, Batch 3500, Batch Loss_train: 0.0022627394646406174
# Epoch 35, Batch 4000, Batch Loss_train: 0.002210862934589386
#
#
# Epoch 35, Epoch Average Loss_train: 0.0022250632781446286, Epoch Average Loss_verif: 0.002172718566049437
#
# Start epoch 36.
#
# Epoch 36, Batch 1, Batch Loss_train: 0.002249376382678747
# Epoch 36, Batch 500, Batch Loss_train: 0.0021522596944123507
# Epoch 36, Batch 1000, Batch Loss_train: 0.0022265228908509016
# Epoch 36, Batch 1500, Batch Loss_train: 0.002275870181620121
# Epoch 36, Batch 2000, Batch Loss_train: 0.0022470394615083933
# Epoch 36, Batch 2500, Batch Loss_train: 0.0022440063767135143
# Epoch 36, Batch 3000, Batch Loss_train: 0.0022326032631099224
# Epoch 36, Batch 3500, Batch Loss_train: 0.002208345104008913
# Epoch 36, Batch 4000, Batch Loss_train: 0.002244038274511695
#
#
# Epoch 36, Epoch Average Loss_train: 0.002225127400446403, Epoch Average Loss_verif: 0.002180617105694608
#
# Start epoch 37.
#
# Epoch 37, Batch 1, Batch Loss_train: 0.0022470448166131973
# Epoch 37, Batch 500, Batch Loss_train: 0.002210934180766344
# Epoch 37, Batch 1000, Batch Loss_train: 0.002192308660596609
# Epoch 37, Batch 1500, Batch Loss_train: 0.00220121955499053
# Epoch 37, Batch 2000, Batch Loss_train: 0.00229647196829319
# Epoch 37, Batch 2500, Batch Loss_train: 0.0022612041793763638
# Epoch 37, Batch 3000, Batch Loss_train: 0.0022100869100540876
# Epoch 37, Batch 3500, Batch Loss_train: 0.0021189795807003975
# Epoch 37, Batch 4000, Batch Loss_train: 0.0021927240304648876
#
#
# Epoch 37, Epoch Average Loss_train: 0.0022247341942521564, Epoch Average Loss_verif: 0.0021727715719511618
#
# Start epoch 38.
#
# Epoch 38, Batch 1, Batch Loss_train: 0.0021970986854285
# Epoch 38, Batch 500, Batch Loss_train: 0.0021630104165524244
# Epoch 38, Batch 1000, Batch Loss_train: 0.002266900846734643
# Epoch 38, Batch 1500, Batch Loss_train: 0.0022648186422884464
# Epoch 38, Batch 2000, Batch Loss_train: 0.0022697066888213158
# Epoch 38, Batch 2500, Batch Loss_train: 0.0022857515141367912
# Epoch 38, Batch 3000, Batch Loss_train: 0.0022497549653053284
# Epoch 38, Batch 3500, Batch Loss_train: 0.0023176753893494606
# Epoch 38, Batch 4000, Batch Loss_train: 0.00224104430526495
#
#
# Epoch 38, Epoch Average Loss_train: 0.002224517036982492, Epoch Average Loss_verif: 0.002168878697499008
#
# Start epoch 39.
#
# Epoch 39, Batch 1, Batch Loss_train: 0.0022087926045060158
# Epoch 39, Batch 500, Batch Loss_train: 0.002224014373496175
# Epoch 39, Batch 1000, Batch Loss_train: 0.0022202078253030777
# Epoch 39, Batch 1500, Batch Loss_train: 0.002190698403865099
# Epoch 39, Batch 2000, Batch Loss_train: 0.002266942523419857
# Epoch 39, Batch 2500, Batch Loss_train: 0.0023458311334252357
# Epoch 39, Batch 3000, Batch Loss_train: 0.002174248220399022
# Epoch 39, Batch 3500, Batch Loss_train: 0.0021022099535912275
# Epoch 39, Batch 4000, Batch Loss_train: 0.0022116389591246843
#
#
# Epoch 39, Epoch Average Loss_train: 0.002224368188298967, Epoch Average Loss_verif: 0.002194126059875103
#
# Start epoch 40.
#
# Epoch 40, Batch 1, Batch Loss_train: 0.002248019678518176
# Epoch 40, Batch 500, Batch Loss_train: 0.0022021515760570765
# Epoch 40, Batch 1000, Batch Loss_train: 0.0023103056009858847
# Epoch 40, Batch 1500, Batch Loss_train: 0.0022246032021939754
# Epoch 40, Batch 2000, Batch Loss_train: 0.0021857689134776592
# Epoch 40, Batch 2500, Batch Loss_train: 0.0022038593888282776
# Epoch 40, Batch 3000, Batch Loss_train: 0.0022976144682615995
# Epoch 40, Batch 3500, Batch Loss_train: 0.002263215370476246
# Epoch 40, Batch 4000, Batch Loss_train: 0.002246994525194168
#
#
# Epoch 40, Epoch Average Loss_train: 0.0022242927932814784, Epoch Average Loss_verif: 0.0021659709944465318
#
# Start epoch 41.
#
# Epoch 41, Batch 1, Batch Loss_train: 0.0022440452594310045
# Epoch 41, Batch 500, Batch Loss_train: 0.0021594297140836716
# Epoch 41, Batch 1000, Batch Loss_train: 0.0021761495154350996
# Epoch 41, Batch 1500, Batch Loss_train: 0.002201549941673875
# Epoch 41, Batch 2000, Batch Loss_train: 0.002285446273162961
# Epoch 41, Batch 2500, Batch Loss_train: 0.002216339111328125
# Epoch 41, Batch 3000, Batch Loss_train: 0.002173074521124363
# Epoch 41, Batch 3500, Batch Loss_train: 0.002209249185398221
# Epoch 41, Batch 4000, Batch Loss_train: 0.0022084596566855907
#
#
# Epoch 41, Epoch Average Loss_train: 0.0022241622097111374, Epoch Average Loss_verif: 0.0021680995742149427
#
# Early stopping triggered at epoch 41

# %%
plt.figure(figsize=(10, 5))
plt.plot(epoch_losses_train, label='Loss on Train')
plt.plot(epoch_losses_verif, label='Loss on Verif')
plt.title('Loss Convergence Curve - MLP')
plt.xlabel('Epoch')
plt.xticks(np.arange(0, 41, 1))
plt.ylabel('Loss')
plt.yscale('log')
plt.ylim(0, max(epoch_losses_train))
plt.legend()
plt.grid(True)
plt.savefig('MLP Loss Convergence.pdf', format='pdf')
plt.show()
# Out:
# /var/folders/b6/kmqmc4952k7__8jzcqjy4jn00000gn/T/ipykernel_58203/2561100035.py:9: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0, max(epoch_losses_train))

# %%
PPMLP_model = PP_MLP(init_method = 'uniform').to(_device_)
PPMLP_model.load_state_dict(torch.load(model_save_path_MLP))
PPMLP_model.eval()

def denormalize(dataset, model, input):
        outputs = dataset.dataset['outputs']
        min_vals_o = outputs.min(axis=0)  
        max_vals_o = outputs.max(axis=0)         

        range_o = max_vals_o - min_vals_o

        return (model(input)*range_o)+min_vals_o

# dataset.dataset['inputs'][0]

# %%
print('Origin        Prediction        Difference\n')
for idx in range(50):
    idx += 1000
    output_NN = denormalize(dataset_test_dn, PPMLP_model, torch.tensor(dataset_test.dataset['inputs'][idx]))
    output_original = dataset_test_dn.dataset['outputs'][idx]

    print(f"{output_original:3.2f}        {float(output_NN):3.6f}        {np.abs(float(output_NN)-output_original):1.8f}")
# Out:
# Origin        Prediction        Difference
#
# 136.00        141.408157        5.40815735
# 134.00        137.804489        3.80448914
# 134.00        139.116058        5.11605835
# 130.00        138.174667        8.17466736
# 150.00        136.823196        13.17680359
# 132.00        140.333572        8.33357239
# 163.00        140.051834        22.94816589
# 159.00        144.204163        14.79583740
# 134.00        144.503677        10.50367737
# 140.00        135.391251        4.60874939
# 136.00        139.055878        3.05587769
# 140.00        134.538086        5.46191406
# 143.00        139.685562        3.31443787
# 150.00        142.533112        7.46688843
# 142.00        145.326843        3.32684326
# 140.00        140.951767        0.95176697
# 142.00        138.306580        3.69342041
# 142.00        142.020004        0.02000427
# 140.00        146.652298        6.65229797
# 154.00        142.950073        11.04992676
# 156.00        144.524216        11.47578430
# 140.00        144.591415        4.59141541
# 140.00        144.783066        4.78306580
# 156.00        143.372177        12.62782288
# 141.00        146.105576        5.10557556
# 136.00        143.966446        7.96644592
# 142.00        142.237564        0.23756409
# 138.00        144.025208        6.02520752
# 138.00        144.232391        6.23239136
# 150.00        146.618027        3.38197327
# 162.00        147.952255        14.04774475
# 141.00        148.926468        7.92646790
# 154.00        145.088577        8.91142273
# 140.00        141.743729        1.74372864
# 160.00        146.894958        13.10504150
# 161.00        146.934052        14.06594849
# 157.00        146.425201        10.57479858
# 140.00        145.224762        5.22476196
# 153.00        143.687454        9.31254578
# 162.00        147.094788        14.90521240
# 141.00        148.926559        7.92655945
# 138.00        147.662659        9.66265869
# 156.00        143.224030        12.77597046
# 136.00        144.536301        8.53630066
# 146.00        140.310272        5.68972778
# 153.00        143.410294        9.58970642
# 153.00        146.099304        6.90069580
# 144.00        145.985992        1.98599243
# 143.00        146.653687        3.65368652
# 156.00        147.501755        8.49824524

# %%
# Collection of Data

section_len = 5000
section_start = 60000

if (section_start + section_len > len(dataset_test_dn.dataset['outputs'])):
    raise ValueError('Length Overflow: The requested section exceeds the available data size.')

inputs = torch.tensor(dataset_test.dataset['inputs'][section_start:section_start + section_len])

outputs_original = dataset_test_dn.dataset['outputs'][section_start:section_start + section_len].squeeze()
outputs_NN = denormalize(dataset_test_dn, PPMLP_model, inputs).detach().numpy().squeeze()

diffs_in_val = outputs_NN - outputs_original

diffs_in_percent = np.where(outputs_original != 0, 
                            (outputs_NN - outputs_original) / outputs_original * 100, 
                            0)

criterion_no_reduction = nn.MSELoss(reduction='none')
diffs_in_loss = criterion_no_reduction(torch.tensor(outputs_NN, dtype=torch.float32), 
                                       torch.tensor(outputs_original, dtype=torch.float32)).detach().numpy()

# %%
fig, axs = plt.subplots(4, 1, figsize=(30, 20))  


axs[0].plot(outputs_original, label='Original Prices', color='blue',linewidth=0.5)
axs[0].plot(outputs_NN, label='Predictions of NN', color='red',linewidth=0.5)
axs[0].set_title('Comparison of Values',fontsize = 16)
axs[0].set_xlabel('Index')
axs[0].set_ylabel('Output Value')
axs[0].legend()

axs[1].plot(diffs_in_val, label='Difference in Value', color='#7262ac',linewidth=0.5)
axs[1].set_title('Difference in Value',fontsize = 16)
axs[1].set_xlabel('Index')
axs[1].set_ylabel('Difference')
axs[1].legend()

axs[2].plot(diffs_in_percent, label='Percentage Difference', color='#2e7ebb',linewidth=0.5)
axs[2].set_title('Difference in Percentage Metric', fontsize = 16)
axs[2].set_xlabel('Index')
axs[2].set_ylabel('Percentage')
axs[2].legend()

axs[3].plot(diffs_in_loss, label='MSE Loss Per Sample', color='#2e974e',linewidth=0.5)
axs[3].set_title('Difference in MSE metric', fontsize = 16)
axs[3].set_xlabel('Index')
axs[3].set_ylabel('MSE Loss')
axs[3].legend()

for ax_i in axs:
    ax_i.grid(True, axis = 'y', linestyle='-.', linewidth=0.5, color='gray')

plt.suptitle('Performances of MLP on Price Prediction',fontsize = 20)
fig.tight_layout(pad=3.0)
plt.savefig('MLP Performances.pdf', format='pdf')
plt.show()

# %%
PPLSTM_model = PP_LSTM(init_method = 'uniform').to(_device_)

loader_train = DataLoader(dataset_train, batch_size=4096, shuffle = True)
loader_verif = DataLoader(dataset_verif, batch_size=4096, shuffle = True)

criterion = nn.MSELoss()
optimizer = optim.Adam(PPLSTM_model.parameters(), lr=0.005)

model_save_path_LSTM = 'PPLSTM_model.pt'
optimizer_save_path_LSTM = 'PPLSTM_optimizer.pt'

# %%
# LSTM Training
continue_training = input("Do you want to continue training or start a new one? (c/n): ").lower() == 'c'

if continue_training and os.path.exists(model_save_path_LSTM) and os.path.exists(optimizer_save_path_LSTM):
    
    PPLSTM_model.load_state_dict(torch.load(model_save_path_LSTM))
    optimizer.load_state_dict(torch.load(optimizer_save_path_LSTM))
    
    print("Continuing training from saved state.")
else:
    print("Starting training from scratch.")

epoch_losses_train = []
epoch_losses_verif = []

max_epochs = 100

patience = 10

timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')

filename = f'LSTM_loss_train & verif_{timestamp}.dat'

with open(filename, 'w') as f:

    best_loss_verif = float('inf')
    patience_counter = 0

    for epoch in range(max_epochs):

        PPLSTM_model.train()  

        running_loss_train = 0.0

        print(f"Start epoch {epoch+1}.\n")

        for batch_idx, (inputs, labels) in enumerate(loader_train):
    
            inputs, labels = inputs.to(_device_), labels.to(_device_).unsqueeze(1)
            
            optimizer.zero_grad()

            outputs = PPLSTM_model(inputs.unsqueeze(1))

            loss = criterion(outputs, labels)

            loss.backward()

            optimizer.step()

            running_loss_train += loss.item()

            if ((batch_idx+1) % 500 == 0) or batch_idx == 0:

                print(f"Epoch {epoch+1}, Batch {batch_idx+1}, Batch Loss_train: {loss.item()}")

        print('\n')

        PPLSTM_model.eval()

        with torch.no_grad():

            running_loss_verif = 0.0

            for batch_idx, (inputs, labels) in enumerate(loader_verif):

                inputs, labels = inputs.to(_device_), labels.to(_device_).unsqueeze(1)

                outputs = PPLSTM_model(inputs.unsqueeze(1))

                loss = criterion(outputs, labels)

                running_loss_verif += loss.item()

        epoch_loss_train = running_loss_train/len(loader_train)
        epoch_loss_verif = running_loss_verif/len(loader_verif)

        epoch_losses_train.append(epoch_loss_train)
        epoch_losses_verif.append(epoch_loss_verif)

        # scheduler_step.step()

        f.write(f'Epoch {epoch+1}, Loss_train: {epoch_loss_train}, Loss_verif: {epoch_loss_verif}\n')
        print(f'Epoch {epoch+1}, Epoch Average Loss_train: {epoch_loss_train}, Epoch Average Loss_verif: {epoch_loss_verif}\n')

        if epoch_loss_verif < best_loss_verif:
            best_loss_verif = epoch_loss_verif
            patience_counter = 0
            torch.save(PPLSTM_model.state_dict(), model_save_path_LSTM)
            torch.save(optimizer.state_dict(), optimizer_save_path_LSTM)
        else :
            patience_counter += 1
        
        if patience_counter >= patience:
            print(f'Early stopping triggered at epoch {epoch+1}')
            break
    
    print('\n')
# Out:
# Starting training from scratch.
# Start epoch 1.
#
# Epoch 1, Batch 1, Batch Loss_train: 0.24742689728736877
# Epoch 1, Batch 500, Batch Loss_train: 0.008893731981515884
# Epoch 1, Batch 1000, Batch Loss_train: 0.00689095351845026
# Epoch 1, Batch 1500, Batch Loss_train: 0.006546767894178629
# Epoch 1, Batch 2000, Batch Loss_train: 0.006819958332926035
# Epoch 1, Batch 2500, Batch Loss_train: 0.0065373945981264114
# Epoch 1, Batch 3000, Batch Loss_train: 0.006627771072089672
# Epoch 1, Batch 3500, Batch Loss_train: 0.006467744708061218
# Epoch 1, Batch 4000, Batch Loss_train: 0.006390899419784546
#
#
# Epoch 1, Epoch Average Loss_train: 0.007915534945268497, Epoch Average Loss_verif: 0.0046353641374897525
#
# Start epoch 2.
#
# Epoch 2, Batch 1, Batch Loss_train: 0.006287185475230217
# Epoch 2, Batch 500, Batch Loss_train: 0.006429392844438553
# Epoch 2, Batch 1000, Batch Loss_train: 0.006325263064354658
# Epoch 2, Batch 1500, Batch Loss_train: 0.0064015151001513
# Epoch 2, Batch 2000, Batch Loss_train: 0.006399489473551512
# Epoch 2, Batch 2500, Batch Loss_train: 0.006186685990542173
# Epoch 2, Batch 3000, Batch Loss_train: 0.006447642110288143
# Epoch 2, Batch 3500, Batch Loss_train: 0.006514492444694042
# Epoch 2, Batch 4000, Batch Loss_train: 0.006453650537878275
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x1092e1370>>
# Traceback (most recent call last):
#   File "/Users/ysrae1/MSc_D/env_TraderT/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 65
#      61 with torch.no_grad():
#      63     running_loss_verif = 0.0
# ---> 65     for batch_idx, (inputs, labels) in enumerate(loader_verif):
#      67         inputs, labels = inputs.to(_device_), labels.to(_device_).unsqueeze(1)
#      69         outputs = PPLSTM_model(inputs.unsqueeze(1))
#
# File ~/MSc_D/env_TraderT/lib/python3.12/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/MSc_D/env_TraderT/lib/python3.12/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/MSc_D/env_TraderT/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[1], line 78, in H5Dataset.__getitem__(self, idx)
#      76 def __getitem__(self, idx):
#      77     input_data = torch.tensor(self.dataset['inputs'][idx], dtype=torch.float32)
# ---> 78     output_data = torch.tensor(self.dataset['outputs'][idx], dtype=torch.float32)
#      79     return input_data, output_data
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10, 5))
plt.plot(epoch_losses_train, label='Loss on Train')
plt.plot(epoch_losses_verif, label='Loss on Verif')
plt.title('Loss Convergence Curve - LSTM')
plt.xlabel('Epoch')
plt.xticks(np.arange(0, 24, 1))
plt.ylabel('Loss')
plt.yscale('log')
plt.ylim(0, max(epoch_losses_train))
plt.legend()
plt.grid(True)
plt.savefig('LSTM Loss Convergence.pdf', format='pdf')
plt.show()
# Out:
# /var/folders/b6/kmqmc4952k7__8jzcqjy4jn00000gn/T/ipykernel_99713/2356318604.py:9: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0, max(epoch_losses_train))

# %%
PPLSTM_model = PP_LSTM(init_method = 'uniform').to(_device_)
PPLSTM_model.load_state_dict(torch.load(model_save_path_LSTM))
PPLSTM_model.eval()
# Out:
# PP_LSTM(
#   (lstm): LSTM(13, 10, batch_first=True)
#   (dense_1): Linear(in_features=10, out_features=5, bias=True)
#   (dense_2): Linear(in_features=5, out_features=3, bias=True)
#   (dense_3): Linear(in_features=3, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
# Collection of Data

section_len = 5000
section_start = 500000

if (section_start + section_len > len(dataset_test_dn.dataset['outputs'])):
    raise ValueError('Length Overflow: The requested section exceeds the available data size.')

inputs = torch.tensor(dataset_test.dataset['inputs'][section_start:section_start + section_len])

outputs_original = dataset_test_dn.dataset['outputs'][section_start:section_start + section_len].squeeze()
outputs_NN = denormalize(dataset_test_dn, PPLSTM_model, inputs.unsqueeze(1)).detach().numpy().squeeze()

diffs_in_val = outputs_NN - outputs_original

diffs_in_percent = np.where(outputs_original != 0, 
                            (outputs_NN - outputs_original) / outputs_original * 100, 
                            0)

criterion_no_reduction = nn.MSELoss(reduction='none')
diffs_in_loss = criterion_no_reduction(torch.tensor(outputs_NN, dtype=torch.float32), 
                                       torch.tensor(outputs_original, dtype=torch.float32)).detach().numpy()

# %%
fig, axs = plt.subplots(4, 1, figsize=(30, 20))  


axs[0].plot(outputs_original, label='Original Prices', color='blue',linewidth=0.5)
axs[0].plot(outputs_NN, label='Predictions of NN', color='red',linewidth=0.5)
axs[0].set_title('Comparison of Values',fontsize = 16)
axs[0].set_xlabel('Index')
axs[0].set_ylabel('Output Value')
axs[0].legend()

axs[1].plot(diffs_in_val, label='Difference in Value', color='#7262ac',linewidth=0.5)
axs[1].set_title('Difference in Value',fontsize = 16)
axs[1].set_xlabel('Index')
axs[1].set_ylabel('Difference')
axs[1].legend()

axs[2].plot(diffs_in_percent, label='Percentage Difference', color='#2e7ebb',linewidth=0.5)
axs[2].set_title('Difference in Percentage Metric', fontsize = 16)
axs[2].set_xlabel('Index')
axs[2].set_ylabel('Percentage')
axs[2].legend()

axs[3].plot(diffs_in_loss, label='MSE Loss Per Sample', color='#2e974e',linewidth=0.5)
axs[3].set_title('Difference in MSE metric', fontsize = 16)
axs[3].set_xlabel('Index')
axs[3].set_ylabel('MSE Loss')
axs[3].legend()

for ax_i in axs:
    ax_i.grid(True, axis = 'y', linestyle='-.', linewidth=0.5, color='gray')

plt.suptitle('Performances of LSTM on Price Prediction',fontsize = 20)
fig.tight_layout(pad=3.0)
plt.savefig('LSTM Performances.pdf', format='pdf')
plt.show()
